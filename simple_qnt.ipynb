# %% [markdown]
# <a href="https://colab.research.google.com/github/LightR-039/API_project_stock_price_reaction/blob/main/simple_qnt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello GitHub 🚀")
# Out:
# Hello GitHub 🚀

# %%
print("testing")
# Out:
# testing
